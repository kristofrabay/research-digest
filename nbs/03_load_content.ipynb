# %% [markdown]
# ## Step 3: get full content for items to pursue

# %%
import sys
sys.path.append('../')

import os
import asyncio
import pandas as pd
from tqdm.asyncio import tqdm_asyncio
from limiter import Limiter
from tenacity import retry, wait_random_exponential, stop_after_attempt

# Rate limiters
jina_limiter = Limiter(rate=250, capacity=250, consume=1)
arxiv_limiter = Limiter(rate=100, capacity=100, consume=1)

from data import ContentManager
manager = ContentManager(base_path="../data")
# Out:
# INFO:data.content_manager:Loaded content index with 233 entries

# %%
df = pd.read_csv("../data/research_items.csv")

# Filter pursue items not yet loaded
if "content_loaded_locally" in df.columns:
    pursue_df = df[(df["scout_decision"] == "pursue") & (df["content_loaded_locally"].isna())]
else:
    pursue_df = df[df["scout_decision"] == "pursue"]

print(f'{len(pursue_df)} items to load from {len(df)} total items')
# Out:
# 52 items to load from 4202 total items

# %% [markdown]
# Define function to get single item (routing between PDF from arxiv and html websites)

# %%
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(3))
async def load_single_item(row):
    url = row["url"]
    title = row.get("title")
    
    if manager.exists(url):
        return {"url": url, "loaded": True, "error": None, "source": manager.get(url)["source"]}
    
    try:
        if "arxiv.org" in url:
            async with arxiv_limiter:
                manager.save_arxiv_pdf(url, title=title, abstract=row.get("relevance"))
            return {"url": url, "loaded": True, "error": None, "source": "arxiv"}
        else:
            async with jina_limiter:
                await manager.fetch_and_save_jina(url, title=title)
            return {"url": url, "loaded": True, "error": None, "source": "jina"}
    except Exception as e:
        return {"url": url, "loaded": False, "error": str(e)[:200], "source": None}

# %% [markdown]
# Run batch

# %%
items = pursue_df.to_dict("records")
print(f"Loading content for {len(items)} items")
# Out:
# Loading content for 52 items

# %%
results = await tqdm_asyncio.gather(*[load_single_item(item) for item in items], desc="Loading content")
# Out:
# Loading content:   0%|          | 0/52 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:   2%|▏         | 1/52 [00:01<01:25,  1.68s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:   8%|▊         | 4/52 [00:02<00:28,  1.71it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  19%|█▉        | 10/52 [00:03<00:09,  4.55it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  21%|██        | 11/52 [00:03<00:11,  3.63it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  25%|██▌       | 13/52 [00:04<00:11,  3.45it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  31%|███       | 16/52 [00:04<00:07,  4.77it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  35%|███▍      | 18/52 [00:04<00:05,  5.91it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  38%|███▊      | 20/52 [00:04<00:05,  6.26it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  40%|████      | 21/52 [00:05<00:04,  6.29it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  42%|████▏     | 22/52 [00:05<00:04,  6.72it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  44%|████▍     | 23/52 [00:05<00:04,  7.08it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  48%|████▊     | 25/52 [00:05<00:03,  8.97it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  52%|█████▏    | 27/52 [00:05<00:02, 10.74it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  56%|█████▌    | 29/52 [00:05<00:02,  7.91it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  60%|█████▉    | 31/52 [00:06<00:02,  7.59it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  65%|██████▌   | 34/52 [00:06<00:02,  7.59it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  67%|██████▋   | 35/52 [00:07<00:02,  5.72it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  71%|███████   | 37/52 [00:07<00:02,  6.38it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  73%|███████▎  | 38/52 [00:07<00:02,  6.29it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  75%|███████▌  | 39/52 [00:07<00:02,  5.77it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  77%|███████▋  | 40/52 [00:08<00:02,  4.19it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  79%|███████▉  | 41/52 [00:08<00:02,  3.86it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  81%|████████  | 42/52 [00:08<00:03,  3.19it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  83%|████████▎ | 43/52 [00:09<00:03,  2.80it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  85%|████████▍ | 44/52 [00:10<00:04,  1.99it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  87%|████████▋ | 45/52 [00:11<00:04,  1.66it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  90%|█████████ | 47/52 [00:12<00:03,  1.64it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  92%|█████████▏| 48/52 [00:13<00:03,  1.16it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  96%|█████████▌| 50/52 [00:14<00:01,  1.45it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content:  98%|█████████▊| 51/52 [00:32<00:04,  4.42s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# Loading content: 100%|██████████| 52/52 [00:35<00:00,  1.46it/s]

# %%
set([result['error'] for result in results if result["error"] is not None])
# Out:
# set()

# %% [markdown]
# Update df

# %%
# Update DataFrame
for result in results:
    mask = df["url"] == result["url"]
    df.loc[mask, "content_loaded_locally"] = result["loaded"] if result["loaded"] else None
    df.loc[mask, "content_load_error"] = result["error"]

# %%
df[~df['content_load_error'].isna()]
# Out:
# Empty DataFrame
# Columns: [focus_area, provider, url, title, source, published, relevance, date_added, scout_decision, scout_confidence, scout_reasoning, scouted_at, content_loaded_locally, content_load_error]
# Index: []

# %%
df.to_csv("../data/research_items.csv", index=False)

# %%
df
# Out:
#            focus_area   provider  \
# 0              dummy1     openai
# 1              dummy2  anthropic
# 2     reasoning_agent     openai
# 3     reasoning_agent     openai
# 4     reasoning_agent     openai
# ...               ...        ...
# 4197            arxiv      arxiv
# 4198            arxiv      arxiv
# 4199            arxiv      arxiv
# 4200            arxiv      arxiv
# 4201            arxiv      arxiv
#
#                                                 url  \
# 0                                https://dummy1.com
# 1                                https://dummy2.com
# 2            https://openai.com/index/gpt-5-2-codex
# 3     https://openai.com/index/introducing-gpt-5-2/
# 4     https://blog.google/products/gemini/gemini-3/
# ...                                             ...
# 4197             https://arxiv.org/abs/2512.10563v1
# 4198             https://arxiv.org/abs/2512.10561v1
# 4199             https://arxiv.org/abs/2512.10551v1
# 4200             https://arxiv.org/abs/2512.10547v1
# 4201             https://arxiv.org/abs/2512.10546v1
#
#                                                   title  \
# 0                                                dummy1
# 1                                                dummy2
# 2                             Introducing GPT-5.2-Codex
# 3                                   Introducing GPT-5.2
# 4     Introducing Gemini 3: our most intelligent mod...
# ...                                                 ...
# 4197  NormCode: A Semi-Formal Language for Context-I...
# 4198  Causal Reasoning Favors Encoders: On The Limit...
# 4199  LLM-Auction: Generative Auction towards LLM-Na...
# 4200  Unlocking the Address Book: Dissecting the Spa...
# 4201                  Bootstrapping not under the null?
#
#                              source   published  \
# 0                       OpenAI Blog  2025-12-01
# 1                             arXiv  2025-12-15
# 2                       OpenAI blog  2025-12-18
# 3                       OpenAI blog  2025-12-11
# 4     Google Blog (Gemini/DeepMind)  2025-11-18
# ...                             ...         ...
# 4197                          arXiv  2025-12-11
# 4198                          arXiv  2025-12-11
# 4199                          arXiv  2025-12-11
# 4200                          arXiv  2025-12-11
# 4201                          arXiv  2025-12-11
#
#                                               relevance  date_added  \
# 0                                       dummy example 1  2025-12-20
# 1                                       dummy example 2  2025-12-21
# 2     Official release of an agentic coding model em...  2025-12-24
# 3     Details GPT-5.2 “Thinking/Pro” modes and API r...  2025-12-24
# 4     Announces Gemini 3 with “thinking”/Deep Think ...  2025-12-24
# ...                                                 ...         ...
# 4197  Summary: Multistep workflows that chain large ...  2025-12-27
# 4198  Summary: In context learning (ICL) underpins r...  2025-12-27
# 4199  Summary: The rapid advancement of large langua...  2025-12-27
# 4200  Summary: The Key-Value (KV) cache is the prima...  2025-12-27
# 4201  Summary: We propose a bootstrap testing framew...  2025-12-27
#
#      scout_decision  scout_confidence  \
# 0           discard              0.95
# 1           discard              0.98
# 2            pursue              0.93
# 3            pursue              0.93
# 4            pursue              0.86
# ...             ...               ...
# 4197         pursue              0.82
# 4198         pursue              0.78
# 4199        discard              0.85
# 4200         pursue              0.78
# 4201        discard              0.72
#
#                                         scout_reasoning  \
# 0     The title and summary are placeholders (“dummy...
# 1     The title and summary are placeholders (“dummy...
# 2     This is an official OpenAI release (credible, ...
# 3     This is a recent (2025-12-11) primary-source r...
# 4     This is a very recent, high-signal primary-sou...
# ...                                                 ...
# 4197  This is directly relevant to agentic workflow ...
# 4198  This is directly relevant to our “reasoning re...
# 4199  This is primarily about mechanism design for L...
# 4200  This looks directly relevant to production con...
# 4201  This is a solid, recent contribution in classi...
#
#                       scouted_at content_loaded_locally content_load_error
# 0     2025-12-26T23:51:12.379244                    NaN                NaN
# 1     2025-12-26T23:51:12.379626                    NaN                NaN
# 2     2025-12-26T23:51:12.380414                   True                NaN
# 3     2025-12-26T23:51:12.380718                   True                NaN
# 4     2025-12-26T23:51:12.380975                   True                NaN
# ...                          ...                    ...                ...
# 4197  2025-12-27T22:33:14.888704                   True                NaN
# 4198  2025-12-27T22:33:14.888972                   True                NaN
# 4199  2025-12-27T22:33:14.889237                    NaN                NaN
# 4200  2025-12-27T22:33:14.889502                   True                NaN
# 4201  2025-12-27T22:33:14.889767                    NaN                NaN
#
# [4202 rows x 14 columns]

# %% [markdown]
# Check file size, delete PDFs

# %%
# %%bash
# for ext in md pdf json csv py ipynb; do
#   count=$(find ../data -name "*.$ext" 2>/dev/null | wc -l | tr -d ' ')
#   if [ $count -gt 0 ]; then
#     size=$(find ../data -name "*.$ext" -exec du -ch {} + 2>/dev/null | grep total$ | awk '{print $1}')
#     printf "%-8s : %4d files, %8s\n" ".$ext" "$count" "$size"
#   fi
# done
# Out:
# .md      : 2483 files,     148M
# .pdf     : 1697 files,     5.9G
# .json    :    1 files,     3.2M
# .csv     :    2 files,      14M
# .py      :    3 files,      16K

# %%
# %%bash
# find ../data/contents -name "*.pdf" -type f -delete

# %%
# %%bash
# for ext in md pdf json csv py ipynb; do
#   count=$(find ../data -name "*.$ext" 2>/dev/null | wc -l | tr -d ' ')
#   if [ $count -gt 0 ]; then
#     size=$(find ../data -name "*.$ext" -exec du -ch {} + 2>/dev/null | grep total$ | awk '{print $1}')
#     printf "%-8s : %4d files, %8s\n" ".$ext" "$count" "$size"
#   fi
# done
# Out:
# .md      : 2483 files,     148M
# .json    :    1 files,     3.2M
# .csv     :    2 files,      14M
# .py      :    3 files,      16K
