# %% [markdown]
# ## Step 3: get full content for items to pursue

# %%
import sys
sys.path.append('../')

import pandas as pd
from tqdm.asyncio import tqdm_asyncio
from limiter import Limiter
from tenacity import retry, wait_random_exponential, stop_after_attempt

# Rate limiters
jina_limiter = Limiter(rate=20, capacity=20, consume=1)
arxiv_limiter = Limiter(rate=100, capacity=100, consume=1)

from data import ContentManager
manager = ContentManager(base_path="../data")
# Out:
# INFO:data.content_manager:Loaded content index with 2995 entries

# %%
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(3))
async def load_single_item(row):
    url = row["url"]
    title = row.get("title")
    
    if manager.exists(url):
        return {"url": url, "loaded": True, "error": None, "source": manager.get(url)["source"]}
    
    try:
        if "arxiv.org" in url:
            async with arxiv_limiter:
                manager.save_arxiv_pdf(url, title=title, abstract=row.get("relevance"))
            return {"url": url, "loaded": True, "error": None, "source": "arxiv"}
        else:
            async with jina_limiter:
                await manager.fetch_and_save_jina(url, title=title)
            return {"url": url, "loaded": True, "error": None, "source": "jina"}
    except Exception as e:
        return {"url": url, "loaded": False, "error": str(e)[:200], "source": None}

# %%
df = pd.read_csv("../data/research_items.csv")

# %% [markdown]
# Run in while loop with max attempts to handle remaining errors

# %%
MAX_ATTEMPTS = 7
attempt = 0

while attempt < MAX_ATTEMPTS:
    attempt += 1
    print(f"\n{'='*50}")
    print(f"Attempt {attempt}/{MAX_ATTEMPTS}")
    print(f"{'='*50}")
    
    # 1. FILTER
    if "content_loaded_locally" in df.columns:
        pursue_df = df[
            (df["scout_decision"] == "pursue") & 
            (df["content_loaded_locally"].isna() | df["content_load_error"].notna())
        ]
    else:
        pursue_df = df[df["scout_decision"] == "pursue"]
    
    if len(pursue_df) == 0:
        print("✅ All items loaded successfully!")
        break
    
    print(f'{len(pursue_df)} items to load from {len(df)} total items')
    
    # 2. CONVERT TO DICT
    items = pursue_df.to_dict("records")

    # 3. RUN BATCH
    results = await tqdm_asyncio.gather(*[load_single_item(item) for item in items], desc="Loading content")

    # 4. UPDATE DF
    for result in results:
        mask = df["url"] == result["url"]
        df.loc[mask, "content_loaded_locally"] = result["loaded"] if result["loaded"] else None
        df.loc[mask, "content_load_error"] = result["error"]
    
    # 5. CHECK ERRORS
    errors = set([result['error'] for result in results if result["error"] is not None])
    if not errors:
        print("✅ No errors in this batch!")
        break
    else:
        print(f"⚠️ {len(errors)} unique errors remain, retrying...")
        
else:
    error_count = df[~df['content_load_error'].isna()].shape[0]
    print(f"❌ Max attempts ({MAX_ATTEMPTS}) reached, {error_count} errors remain")
# Out:
# ==================================================
# Attempt 1/7
# ==================================================
# 434 items to load from 5595 total items
# Loading content:   0%|          | 0/434 [00:00<?, ?it/s]INFO:data.content_manager:Saved arXiv: 2503.17407
# INFO:data.content_manager:Saved arXiv: 2512.23171v1
# INFO:data.content_manager:Saved arXiv: 2512.20460v2
# INFO:data.content_manager:Saved arXiv: 2512.23167v1
# INFO:data.content_manager:Saved arXiv: 2512.22238v1
# INFO:data.content_manager:Saved arXiv: 2512.23165v1
# INFO:data.content_manager:Saved arXiv: 2512.20291v2
# INFO:data.content_manager:Saved arXiv: 2512.23145v1
# INFO:data.content_manager:Saved arXiv: 2512.22236v1
# INFO:data.content_manager:Saved arXiv: 2512.23578v1
# INFO:data.content_manager:Saved arXiv: 2512.22495v1
# INFO:data.content_manager:Saved arXiv: 2509.25420
# INFO:data.content_manager:Saved arXiv: 2512.23572v1
# INFO:data.content_manager:Saved arXiv: 2512.22492v1
# INFO:data.content_manager:Saved arXiv: 2508.05618
# INFO:data.content_manager:Saved arXiv: 2512.23565v1
# INFO:data.content_manager:Saved arXiv: 2512.22473v1
# INFO:data.content_manager:Saved arXiv: 2508.05615
# INFO:data.content_manager:Saved arXiv: 2512.23562v1
# INFO:data.content_manager:Saved arXiv: 2512.22471v1
# INFO:data.content_manager:Saved arXiv: 2512.23557v1
# INFO:data.content_manager:Saved arXiv: 2512.22470v1
# INFO:data.content_manager:Saved arXiv: 2505.14656
# INFO:data.content_manager:Saved arXiv: 2512.23547v1
# INFO:data.content_manager:Saved arXiv: 2512.22467v1
# INFO:data.content_manager:Saved arXiv: 2506.06017
# INFO:data.content_manager:Saved arXiv: 2512.23545v1
# INFO:data.content_manager:Saved arXiv: 2512.22457v1
# INFO:data.content_manager:Saved arXiv: 2512.23524v1
# INFO:data.content_manager:Saved arXiv: 2512.22455v1
# INFO:data.content_manager:Saved arXiv: 2512.23518v1
# INFO:data.content_manager:Saved arXiv: 2512.22443v1
# INFO:data.content_manager:Saved arXiv: 2512.23515v1
# INFO:data.content_manager:Saved arXiv: 2512.22442v1
# INFO:data.content_manager:Saved arXiv: 2512.23512v1
# INFO:data.content_manager:Saved arXiv: 2512.22435v1
# INFO:data.content_manager:Saved arXiv: 2512.23504v1
# INFO:data.content_manager:Saved arXiv: 2512.22431v1
# INFO:data.content_manager:Saved arXiv: 2512.23499v1
# INFO:data.content_manager:Saved arXiv: 2512.22428v1
# INFO:data.content_manager:Saved arXiv: 2512.23494v1
# INFO:data.content_manager:Saved arXiv: 2512.22420v1
# INFO:data.content_manager:Saved arXiv: 2512.23491v1
# INFO:data.content_manager:Saved arXiv: 2512.22418v1
# INFO:data.content_manager:Saved arXiv: 2512.23489v1
# INFO:data.content_manager:Saved arXiv: 2512.22416v1
# INFO:data.content_manager:Saved arXiv: 2512.23487v1
# INFO:data.content_manager:Saved arXiv: 2512.22404v1
# INFO:data.content_manager:Saved arXiv: 2512.23485v1
# INFO:data.content_manager:Saved arXiv: 2512.22403v1
# INFO:data.content_manager:Saved arXiv: 2512.23480v1
# INFO:data.content_manager:Saved arXiv: 2512.22402v1
# INFO:data.content_manager:Saved arXiv: 2512.23471v1
# INFO:data.content_manager:Saved arXiv: 2512.22398v1
# INFO:data.content_manager:Saved arXiv: 2512.23461v1
# INFO:data.content_manager:Saved arXiv: 2512.22396v1
# INFO:data.content_manager:Saved arXiv: 2512.23457v1
# INFO:data.content_manager:Saved arXiv: 2512.22387v1
# INFO:data.content_manager:Saved arXiv: 2512.23453v1
# INFO:data.content_manager:Saved arXiv: 2512.22386v1
# INFO:data.content_manager:Saved arXiv: 2510.16844
# INFO:data.content_manager:Saved arXiv: 2512.23448v1
# INFO:data.content_manager:Saved arXiv: 2512.22385v1
# INFO:data.content_manager:Saved arXiv: 2510.00156
# INFO:data.content_manager:Saved arXiv: 2512.23447v1
# INFO:data.content_manager:Saved arXiv: 2512.22382v1
# INFO:data.content_manager:Saved arXiv: 2512.23440v1
# INFO:data.content_manager:Saved arXiv: 2512.22378v1
# INFO:data.content_manager:Saved arXiv: 2408.06361
# INFO:data.content_manager:Saved arXiv: 2512.23434v1
# INFO:data.content_manager:Saved arXiv: 2512.22367v1
# INFO:data.content_manager:Saved arXiv: 2402.02315
# INFO:data.content_manager:Saved arXiv: 2512.23431v1
# INFO:data.content_manager:Saved arXiv: 2512.22364v1
# INFO:data.content_manager:Saved arXiv: 2512.23430v1
# INFO:data.content_manager:Saved arXiv: 2512.22351v1
# INFO:data.content_manager:Saved arXiv: 2512.23427v1
# INFO:data.content_manager:Saved arXiv: 2512.22337v1
# INFO:data.content_manager:Saved arXiv: 2512.23424v1
# INFO:data.content_manager:Saved arXiv: 2512.22336v1
# INFO:data.content_manager:Saved arXiv: 2406.11903
# INFO:data.content_manager:Saved arXiv: 2512.23422v1
# INFO:data.content_manager:Saved arXiv: 2512.22334v1
# INFO:data.content_manager:Saved arXiv: 2512.23415v1
# INFO:data.content_manager:Saved arXiv: 2512.22326v1
# INFO:data.content_manager:Saved arXiv: 2512.23412v1
# INFO:data.content_manager:Saved arXiv: 2512.22323v1
# INFO:data.content_manager:Saved arXiv: 2512.23410v1
# INFO:data.content_manager:Saved arXiv: 2512.22322v1
# INFO:data.content_manager:Saved arXiv: 2512.23407v1
# INFO:data.content_manager:Saved arXiv: 2512.22318v1
# INFO:data.content_manager:Saved arXiv: 2512.23385v1
# INFO:data.content_manager:Saved arXiv: 2512.22315v1
# INFO:data.content_manager:Saved arXiv: 2508.16260
# INFO:data.content_manager:Saved arXiv: 2512.23372v1
# INFO:data.content_manager:Saved arXiv: 2512.22309v1
# INFO:data.content_manager:Saved arXiv: 2512.23367v1
# INFO:data.content_manager:Saved arXiv: 2512.22306v1
# INFO:data.content_manager:Saved arXiv: 2512.23366v1
# INFO:data.content_manager:Saved arXiv: 2512.22305v1
# INFO:data.content_manager:Saved arXiv: 2512.23356v1
# INFO:data.content_manager:Saved arXiv: 2512.22303v1
# INFO:data.content_manager:Saved arXiv: 2512.23353v1
# INFO:data.content_manager:Saved arXiv: 2512.21798v2
# INFO:data.content_manager:Saved arXiv: 2512.23343v1
# INFO:data.content_manager:Saved arXiv: 2512.22293v1
# INFO:data.content_manager:Saved arXiv: 2512.23340v1
# INFO:data.content_manager:Saved arXiv: 2512.22291v1
# INFO:data.content_manager:Saved arXiv: 2512.23330v1
# INFO:data.content_manager:Saved arXiv: 2512.22288v1
# INFO:data.content_manager:Saved arXiv: 2512.23328v1
# INFO:data.content_manager:Saved arXiv: 2512.21580v2
# INFO:data.content_manager:Saved arXiv: 2512.04550
# INFO:data.content_manager:Saved arXiv: 2512.23310v1
# INFO:data.content_manager:Saved arXiv: 2512.22280v1
# INFO:data.content_manager:Saved arXiv: 2512.20092
# INFO:data.content_manager:Saved arXiv: 2512.23308v1
# INFO:data.content_manager:Saved arXiv: 2512.22275v1
# INFO:data.content_manager:Saved arXiv: 2512.23307v1
# INFO:data.content_manager:Saved arXiv: 2512.22271v1
# INFO:data.content_manager:Saved arXiv: 2512.23300v1
# INFO:data.content_manager:Saved arXiv: 2512.22266v1
# INFO:data.content_manager:Saved arXiv: 2512.23292v1
# INFO:data.content_manager:Saved arXiv: 2512.21257v2
# INFO:data.content_manager:Saved arXiv: 2512.23289v1
# INFO:data.content_manager:Saved arXiv: 2512.21110v2
# INFO:data.content_manager:Saved arXiv: 2512.23280v1
# INFO:data.content_manager:Saved arXiv: 2512.22258v1
# INFO:data.content_manager:Saved arXiv: 2512.23260v1
# INFO:data.content_manager:Saved arXiv: 2512.22256v1
# INFO:data.content_manager:Saved arXiv: 2506.18096
# INFO:data.content_manager:Saved arXiv: 2512.23244v1
# INFO:data.content_manager:Saved arXiv: 2512.22255v1
# INFO:data.content_manager:Saved arXiv: 2512.23236v1
# INFO:data.content_manager:Saved arXiv: 2512.22252v1
# INFO:data.content_manager:Saved arXiv: 2507.21504
# INFO:data.content_manager:Saved arXiv: 2512.23214v1
# MuPDF error: syntax error: cannot find ExtGState resource 'gs0'
# INFO:data.content_manager:Saved arXiv: 2512.22247v1
# INFO:data.content_manager:Saved arXiv: 2512.23213v1
# INFO:data.content_manager:Saved arXiv: 2512.22245v1
# INFO:data.content_manager:Saved arXiv: 2512.23206v1
# INFO:data.content_manager:Saved arXiv: 2512.20745v2
# INFO:data.content_manager:Saved arXiv: 2512.23184v1
# INFO:data.content_manager:Saved arXiv: 2512.22240v1
# INFO:data.content_manager:Saved arXiv: 2512.23173v1
# INFO:data.content_manager:Saved arXiv: 2512.20491v4
# Loading content:   0%|          | 1/434 [04:45<34:22:23, 285.78s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://platform.openai.com/docs/guides/tools-connectors-mcp
# Loading content:  82%|████████▏ | 357/434 [04:47<00:43,  1.77it/s]  INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://newsletter.weaviate.io/p/94-faster-keyword-search-multi-vector-embeddings-nvidia-integrations-and-much-more
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://aclanthology.org/2024.findings-acl.91/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://aclanthology.org/2025.emnlp-main.211/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://blog.modelcontextprotocol.io/posts/2025-11-03-using-server-instructions/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.anthropic.com/engineering/effective-context-engineering-for-ai-agents
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://aclanthology.org/2025.findings-acl.1199/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.businesswaretech.com/blog/benchmarking-ai-on-tables-and-engineering-drawings-results-findings
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://zju-real.github.io/gui-rcpo/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://deepprune.github.io/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://qwenlm.github.io/blog/qwen3-embedding/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://learn.microsoft.com/en-us/azure/databricks/vector-search/query-vector-search
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://docs.kensho.com/llmreadyapi/mcp
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.anthropic.com/engineering/building-agents-with-the-claude-agent-sdk/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/modelcontextprotocol/modelcontextprotocol/releases
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://pmc.ncbi.nlm.nih.gov/articles/PMC11645129/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.llamaindex.ai/blog/llamaindex-newsletter-2024-12-24
# INFO:data.content_manager:Saved via Jina: https://gemini.google/overview/deep-research/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/SalesforceAIResearch/UniDOC-Bench
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://platform.openai.com/docs/mcp
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/UlrickBL/multimodal_reranker
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://reducto.ai/blog/sota-table-parsing
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/a2aproject/A2A
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/llm-lab-org/Multimodal-RAG-Survey
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/opendatalab/TRivia
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://openai.com/index/o1-and-new-tools-for-developers/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://platform.openai.com/docs/changelog/launched-structured-outputs
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.llamaindex.ai/blog/mastering-pdfs-extracting-sections-headings-paragraphs-and-tables-with-cutting-edge-parser-faea18870125
# Loading content:  88%|████████▊ | 384/434 [04:50<00:26,  1.92it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.anthropic.com/research/contextual-retrieval
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/jinaai/jina-reranker-v2-base-multilingual
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/kensho-technologies/kfinance
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/Finance-LLMs/FinMCP
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/opendatalab/TRivia-3B
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://openai.com/te-IN/index/gpt-5-2-for-science-and-math/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.deeplearning.ai/courses/fine-tuning-and-reinforcement-learning-for-llms-intro-to-post-training/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://claude.com/connectors/daloopa
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.prnewswire.com/news-releases/alphasense-ai-search-and-market-intelligence-platform-now-available-in-new-aws-ai-marketplace-agents-and-tools-category-302506998.html
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://neo4j.com/blog/genai/what-is-graphrag/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/bloomberg/m3docrag
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/blog/hansolosan/granite-embedding-r2
# Loading content:  91%|█████████ | 396/434 [04:51<00:18,  2.01it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://claude.com/blog/organization-skills-and-directory
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://github.com/langchain-ai/open_deep_research
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/BAAI/bge-reranker-large
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://epoch.ai/frontiermath
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://jina.ai/news/late-chunking-in-long-context-embedding-models/
# INFO:data.content_manager:Saved via Jina: https://www.alpha-sense.com/resources/research-articles/generative-ai-in-private-equity/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://claude.com/connectors/pitchbook
# Loading content:  93%|█████████▎| 403/434 [04:52<00:14,  2.07it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://openai.com/index/chain-of-thought-monitoring/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://docs.llamaindex.ai/en/stable/examples/cookbooks/contextual_retrieval/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/blog/UlrickBL/building-and-evaluating-multimodal-rerankers
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://simonw.substack.com/p/large-language-models-can-run-tools
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://standardmetrics.io/library/portfolio-monitoring-tools-managing-a-portfolio-with-ai-and-automation/
# Loading content:  94%|█████████▍| 408/434 [04:53<00:12,  2.15it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.deeplearning.ai/short-courses/reinforcement-fine-tuning-llms-grpo/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://jina.ai/news/jina-embeddings-v3-a-frontier-multilingual-embedding-model
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://medium.com/box-developer-blog/contextual-retrieval-in-retrieval-augmented-generation-rag-49b7bff0c5b7
# Loading content:  95%|█████████▍| 411/434 [04:54<00:10,  2.18it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://openai.com/index/evaluating-chain-of-thought-monitorability/
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/jinaai/jina-embeddings-v3
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.deeplearning.ai/short-courses/llms-as-operating-systems-agent-memory/
# Loading content:  95%|█████████▌| 414/434 [04:54<00:08,  2.25it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://simonw.substack.com/p/how-i-use-llms-to-help-me-write-code
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://changelog.langchain.com/announcements/deepagents-0-2-release-for-more-autonomous-agents
# Loading content:  96%|█████████▌| 416/434 [04:56<00:08,  2.20it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.mongodb.com/community/forums/t/announcing-hybrid-search-support-via-rankfusion/324476
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://developer.nvidia.com/blog/nvidia-text-embedding-model-tops-mteb-leaderboard/
# Loading content:  96%|█████████▋| 418/434 [04:56<00:07,  2.24it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://docs.claude.com/en/docs/build-with-claude/context-editing
# Loading content:  97%|█████████▋| 419/434 [04:57<00:06,  2.27it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://docs.claude.com/fr/docs/build-with-claude/pdf-support
# Loading content:  97%|█████████▋| 420/434 [04:57<00:05,  2.34it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/Qwen/Qwen2-VL-7B-Instruct
# Loading content:  97%|█████████▋| 421/434 [04:57<00:05,  2.33it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://unstract.com/blog/extract-table-from-pdf/
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://changelog.langchain.com/announcements/langmem-sdk-for-long-term-agent-memory
# Loading content:  97%|█████████▋| 423/434 [04:57<00:04,  2.74it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://docs.claude.com/en/docs/agents-and-tools/tool-use/memory-tool
# Loading content:  98%|█████████▊| 424/434 [04:58<00:03,  2.76it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://blog.langchain.com/langchain-state-of-ai-2024/
# Loading content:  98%|█████████▊| 425/434 [04:58<00:03,  2.90it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://openai.com/index/introducing-deep-research/
# Loading content:  98%|█████████▊| 426/434 [05:00<00:05,  1.47it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://azure.microsoft.com/en-us/blog/introducing-deep-research-in-azure-ai-foundry-agent-service/
# Loading content:  98%|█████████▊| 427/434 [05:02<00:05,  1.30it/s]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://cohere.com/blog/embed-4
# Loading content:  99%|█████████▊| 428/434 [05:05<00:08,  1.43s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.getdynamiq.ai/post/llm-guardrails-in-private-equity-how-to-scale-genai-safely-across-portfolio-companies
# Loading content:  99%|█████████▉| 429/434 [05:16<00:17,  3.56s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.anthropic.com/solutions/financial-services
# INFO:data.content_manager:Saved via Jina: https://www.itpro.com/technology/artificial-intelligence/openai-chatgpt-atlas-ai-browser-prompt-injection-attack-risk
# Loading content:  99%|█████████▉| 430/434 [05:17<00:11,  2.85s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://huggingface.co/spaces/HuggingFaceH4/blogpost-scaling-test-time-compute
# Loading content: 100%|█████████▉| 432/434 [05:17<00:03,  1.74s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://www.techradar.com/ai-platforms-assistants/testing-chatgpt-gemini-and-claude-in-the-multimodal-maze
# Loading content: 100%|█████████▉| 433/434 [05:18<00:01,  1.57s/it]INFO:httpx:HTTP Request: POST https://r.jina.ai/ "HTTP/1.1 200 OK"
# INFO:data.content_manager:Saved via Jina: https://jina.ai/reranker/
# Loading content: 100%|██████████| 434/434 [05:20<00:00,  1.35it/s]
# ✅ No errors in this batch!

# %% [markdown]
# Save back to DF once all attempts are exhausted

# %%
df.to_csv("../data/research_items.csv", index=False)

# %% [markdown]
# Check file size, delete PDFs

# %%
# %%bash
# for ext in md pdf json csv py ipynb; do
#   count=$(find ../data -name "*.$ext" 2>/dev/null | wc -l | tr -d ' ')
#   if [ $count -gt 0 ]; then
#     size=$(find ../data -name "*.$ext" -exec du -ch {} + 2>/dev/null | grep total$ | awk '{print $1}')
#     printf "%-8s : %4d files, %8s\n" ".$ext" "$count" "$size"
#   fi
# done
# Out:
# .md      : 3389 files,     197M
# .pdf     :  314 files,     986M
# .json    :    1 files,     3.7M
# .csv     :    2 files,      36M
# .py      :    3 files,      16K

# %%
# %%bash
# find ../data/contents -name "*.pdf" -type f -delete

# %%
# %%bash
# for ext in md pdf json csv py ipynb; do
#   count=$(find ../data -name "*.$ext" 2>/dev/null | wc -l | tr -d ' ')
#   if [ $count -gt 0 ]; then
#     size=$(find ../data -name "*.$ext" -exec du -ch {} + 2>/dev/null | grep total$ | awk '{print $1}')
#     printf "%-8s : %4d files, %8s\n" ".$ext" "$count" "$size"
#   fi
# done
# Out:
# .md      : 3389 files,     197M
# .json    :    1 files,     3.7M
# .csv     :    2 files,      36M
# .py      :    3 files,      16K
